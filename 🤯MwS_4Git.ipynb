# %% [markdown]
# # 📚🪓⏱️ **`Matvejev word Shredder`** (MwS)
# or the burial of `Byte-pair Encoding`
#
# ---
#
#  * ### 🖱️ **One-click**
#  * ### 🏷️ **Zero-label**
#  * ### ⚡️ **Fast**
#  * ### 🔪 **Surgical**
#  * # 🧬🧠🧨 **`Morphemic Tokenizer`** ✂️🧩🧾
#  ---

# %% [markdown]
# Этот проект посвящён улучшению классического `char-level Byte-pair encoding` (далее — `cBPE`) для аппроксимации морфемных разбиений. Наша задача состояла в существенной модификации и стабилизации паттернов, по которым производится слияние меньших токенов в токены большей длины на основе их совместной встречаемости.
#
# Принципиальным в данной работе было сохрание unsupervised-природы оригинального `BPE` для удобства применения на больших неразмеченных текстовых данных.
#
# **`Matvejev word Shredder`** при соответствующей настройке может существенно улучшить обощающую способность генеративных языковых моделей, гораздо эффективнее сокращая размер словаря, чем это делает большинство современных механизмов токенизации. Наибольшую ценность он будет представлять для морфологически богатых языков, а также языков с развитыми паттернами словообразования.
#
# Перспективы, которые мы видим для **`MwS`**:
#
# * Комбинация с **`Multi-Token Prediction`** (как, например, в *`DeepSeek R1`*). Возможность предсказывать сразу несколько (2-5) токенов, при учёте корректности морфемных границ позволит увеличить качество генерации при снижении времени генерации от **`Multi-Token Prediction`**.
# * **Морфемные разбиения уменьшат размер эмбеддинга на токен**, что увеличит скорость обучения и инференса, либо **улучшит качество** при сохранении стандартных размеров. У стандартного `BPE` часты ситуации, когда одни токены представляют из себя **целые слова** или даже **бóльшие конструкции**, а другие - **наборы из байтов**, которые вообще могут быть не видны пользователю. Один токен в **`MwS`** будет представлять из себя последовательность из нескольких символов, что существенно снизит разброс кодируемой эмбеддингом информации. Каждая такая последовательность будет нести в себе меньше содержания, чем целое слово, из-за чего представление слова будет гораздо более чётким.
# * В то же время, чёткость размеченных морфемных границ позволит языковым моделям меньшей размерности **быстрее усваивать грамматические и деривационные паттерны**, а также существенно **экономить на размере словаря**.

# %% [markdown]
# # Imports

# %%
# %pip install --quiet datasets==2.15.0 pymorphy3==2.0.4 transformers==4.51.3
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.1/54.1 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 92.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 79.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 94.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2023.10.0 which is incompatible.

# %%
import json
import os
import math

from collections import Counter
from dataclasses import dataclass
from functools import lru_cache
from itertools import pairwise, chain
from math import log
from pathlib import Path
from typing import Dict, List, Optional, Set, Tuple

import pymorphy3
import regex as re
import huggingface_hub
from huggingface_hub import HfApi, PyTorchModelHubMixin, interpreter_login, snapshot_download
from huggingface_hub.utils import SoftTemporaryDirectory
from tempfile import TemporaryDirectory as SoftTemporaryDirectory
from tqdm.auto import tqdm, trange

# %%
from google.colab import userdata
huggingface_hub.login(token=userdata.get('hf_tok'))

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from string import punctuation

username = HfApi().whoami()["name"]
REPO_NAME = f"{username}/Matvejev_word_shredder"

print(f"Repository: '{REPO_NAME}'")
SEED = 0xC0FFEE

alphas ='абвгдеёжзийклмнопрстуфхцчшщъыьэюя'
ALPHABET = set(fr' {alphas}{alphas.upper()}0123456789{punctuation}')
print(len(ALPHABET), f'{ALPHABET=}')
# Out:
# Repository: 'YourMasya/Matvejev_word_shredder'
# 109 ALPHABET={'э', '0', 'И', 'Ж', '_', 'б', ')', '&', 'Т', 'К', 'а', 'Г', '4', 'Х', '9', 'ф', '-', ',', 'ъ', ']', 'М', '{', 'В', '^', '/', '>', '=', '@', '%', ';', 'Е', '3', 'Р', ':', 'н', 'О', '"', '|', 'Ф', 'Ч', '?', '5', 'Д', 'в', '8', '~', '\\', 'й', 'Ш', 'Ь', 'м', 'ь', '<', ' ', '.', 'к', 'Н', 'З', 'Й', 'ю', 'я', "'", '*', 'Э', 'Ъ', '!', 'Щ', '`', 'Б', 'ш', 'Ы', 'о', 'Ц', '$', 'е', 'т', 'у', 'щ', 'х', '[', '}', '+', 'ж', 'ё', 'ц', '7', '6', 'А', 'Ё', 'Ю', '2', 'р', 'п', 'Л', '(', 'г', 'з', 'С', 'и', 'л', 'ы', 'У', 'Я', 'с', 'д', '1', 'ч', 'П', '#'}
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# # Data and useful tools

# %% [markdown]
# Обучение токенизатора с помощью статистических инструментов на больших корпусах текстов для усмотрения морфологических и деривационных зависимостей видится нам абсолютно бесполезным. Данные в таком случае являются несбалансированными. Токенизатор сможет подогнаться под выборку, но что насчёт генеральной совокупности, включающей в себя все возможные формы данного слова, аналогичные формы других слов и однокоренные слова? При таком подходе успех маловероятен. Это противоречит конечной цели при тренировке любой языковой модели — увеличению обобщающей способности (желательно на множестве разнообразных задач).
#
# Мы утверждаем, что именно поморфемная токенизация является ключевой предпосылкой для экономии и эффективности. Выделим основные типы проблем, возникающие при неправильной токенизации и распределим их по убыванию: от самой до наименее критичной.
#
# 1.   **Нарушены гарницы** морфем: ```['пер', 'ечит']```
# 2.   Несколько морфем объеденено в один **длинный** токен:  ```['перечит']``` = Переобучение.
# 3.   Составляющие одной морфемы **не объеденены** в один токен: ```['пе', ре', 'ч', 'ит']``` = Недообучение.
#
# Некоторые формы слова могут отсутствовать в корпусе, несмотря на возможность появления. Впоследствии токенизатор будет разбивать однокоренные слова и даже формы одного слова так, что языковой модели будет тяжелее усмотреть важные граматические и лексические зависимости.
#
# ---

# %% [markdown]
# Сравним два типа разбиений и обсудим, почему одно лучше другого:
# *   **Хорошие разбиения**:
# ```['пере', 'чит', 'ыва', 'ющ', 'ая', 'ся']```; ```['про', 'чит', 'а', 'вш', 'ая']```; ```['чит', 'а', 'ет']```
#
# У слов выделен общий корень и окончание **-ая-**. У представлений 1 и 2 слов уже созданы предпосылки для усмотрения общих лексического значения, женского рода, единственного числа и именительного падежа. Корректны границы приставок, суффикса **-ыва-**, маркирующего несовершенный вид, постфикса **-ся**, маркирующего пассивный залог и свидетельствующих о различиях в информации. Форма действительного причастия прошедшего времени маркируется суффиксом **-вш-**, выделение суффикса **-ущ-** говорит о форме действительного причастия настоящего времени, образованного от глагола 1-го спряжения с основой на гласную. Последний фактор указывает на взаимную информацию с предыдущим суффиксом, что окажется полезным при генерации.
#
# *   **Плохие разбиения**: ```['пе', 'речи', 'тыва', 'вшая', 'ся']```; ```['прочит', 'авши', 'й']```; ```['чита', 'вши', 'й']```
#
# Данное разбиение содержит все 3 проблемы. Нарушение границ морфем, например, в токене **-тыва-** будет провоцировать модель локализовать в одном эмбеддинге как информацию из корня слова, так и из суффикса, что затруднит обобщение информации со словами, где суффикс **-ыва-** выделен корректно или выделенный токен содержит в себе часть этого суффикса либо помимо самого суффикса — часть другой морфемы. В токене -прочит- наблюдаем слияние приставки и суффикса, из-за чего модели понадобится существенно больше данных для нахождения сходств и различий с токенами **-почит-**, **-перечит-** **-недочит-** и т.д.
#
#
# ---

# %% [markdown]
# **Вывод**. Множество сходств и различий в морфемных составах слов при обучении модели будут связываться со сходствами и различиями в употреблениях — окружениях этих слов. Значение слова — и есть его употребление. И оно в том числе складывается из особенностей употребления морфем в контекстах, гораздо более широких, чем слово.
#
# **Хороший датасет**, в соответствии с нашими потребностями должен будет удовлетворить 3 критериям:
#
# 1.   **Разнообразие форм** одного слова (прочитать, прочитали, прочитает, прочитайте и т.д.)
# 2.   **Разнообразие однокоренных** и **этимологически родственных** слов (перечитывать, отчитать, почитать, почитание, прочтение, читка и т.д.)
# 3.   Единичность вхождения / **уникальность** в датасете **каждого слова**
#
# Критерии 1 и 2 будут удовлетворены при обучении на любом большом корпусе текстов (а на таких сейчас и учат LLM-ки). Мы же создадим игрушечный датасет из однокоренных слов и просклоняем их с помощью `pymorphy`

# %%
# Using GPT-4 pre-tokenization pattern
WHITESPACE_SPLITTER = re.compile(r"""'(?i:[sdmt]|ll|ve|re)|[^\r\n\p{L}\p{N}]?+\p{L}+|\p{N}{1,3}| ?[^\s\p{L}\p{N}]++[\r\n]*|\s*[\r\n]|\s+(?!\S)|\s+""")

def decline_words(data: Set,
                  to_lower: bool=True):
  wordforms = set()
  morph = pymorphy3.MorphAnalyzer()

  for token in data:
    token = token.lower() if to_lower else token
    wordforms |= {p.word for p in morph.parse(token)[0].lexeme
    if p.word not in wordforms}
  return wordforms

# %%
toy_data = {
  'писать', 'написать', 'написывать', 'прописать', 'прописывать',
  'прописаться', 'прописываться', 'написаться', 'написываться', 'подписать',
  'подписывать', 'подписаться', 'подписываться', 'синий', 'синеть', 'осенний',
  'синь', 'синька', 'осень', 'пописать', 'пописывать', 'читать', 'прочитать',
  'начитаться', 'дочитать', 'прочитывать', 'прочитываться', 'прочитаться',
  'читаться', 'дочитывать', 'дочитаться', 'дочитываться', 'зачитать',
  'зачитаться', 'зачитывать', 'зачитываться', 'почитать', 'почитывать',
  'почитаться', 'писька', 'писюлька', 'перечитать', 'переписать',
  'переписывать', 'перечитывать', 'переписываться', 'переписаться',
  'перечитаться', 'перечитываться', 'читка', 'перепись', 'пропись'
}

toy_data = decline_words(toy_data)
toy_data = [" ".join(toy_data)]
print(WHITESPACE_SPLITTER.findall(toy_data[0]))
# Out:
# ['прочитываемыми', ' подписавшейся', ' прочитывающимся', ' пописываемый', ' зачитывавшихся', ' дочитавшимся', ' прочитающуюся', ' зачитавшееся', ' подписываться', ' подписало', ' перепишите', ' прописываемых', ' дочитало', ' переписывавших', ' дочитанными', ' зачитывающая', ' почитает', ' зачитывавшегося', ' прописанного', ' зачитанного', ' пописаны', ' подписывали', ' зачитались', ' перечитывавшимися', ' зачитывайся', ' подписывающий', ' написывающемся', ' почитываемое', ' подписавшие', ' синевшее', ' перечитан', ' перепишешься', ' дочитавшем', ' напишущейся', ' подписанные', ' перепишущаяся', ' написалось', ' переписало', ' написавшихся', ' переписывающегося', ' зачитывавшем', ' перечитывающихся', ' написываемою', ' подписываете', ' прочитали', ' пописавши', ' перепишут', ' перечитавшегося', ' написавшим', ' напишущийся', ' читанное', ' написываемым', ' подписался', ' подписывающем', ' переписывавшим', ' прописывалось', ' прочитавшей', ' синевшею', ' перечитываемыми', ' попишет', ' переписывающим', ' читавшаяся', ' дочитавшемуся', ' написывайте', ' пописываю', ' дочитывающимся', ' осенях', ' дочитывающемся', ' написавшейся', ' пописываемой', ' попишите', ' прописей', ' дочитанное', ' прочитывающуюся', ' синело', ' дочитываемые', ' перепишущимися', ' зачитывавшего', ' пописывающие', ' читаешься', ' подписывавшемуся', ' переписанное', ' писавших', ' перечитывавшею', ' написанном', ' написывающих', ' читала', ' попиши', ' переписывающаяся', ' читки', ' перечитывайте', ' перечитанным', ' перечитающеюся', ' прописывала', ' дочитываются', ' написалась', ' почитывающие', ' осення', ' подписывающеюся', ' дочитывалось', ' дочитывало', ' переписывающей', ' перепишущемся', ' прочитающиеся', ' зачитывалось', ' переписывался', ' переписывающееся', ' зачитанный', ' начитавшимся', ' перечитывает', ' синейшего', ' напишущеюся', ' подписывавшеюся', ' переписываемая', ' перечитающиеся', ' прочитывающая', ' подписанных', ' прочитанное', ' читающееся', ' дочитываться', ' подписывайтесь', ' перепишущемуся', ' переписываясь', ' писав', ' почитающей', ' подпишемся', ' написывавшему', ' прописывающаяся', ' прописываемы', ' подписывавшейся', ' пропишет', ' пописав', ' прописывающими', ' почитаемому', ' перечитывающуюся', ' читаемое', ' прописало', ' прописавшаяся', ' пропишемте', ' переписался', ' перечитывавшиеся', ' перечитаешься', ' зачитывающемся', ' синькой', ' синьками', ' прописывающий', ' подписываемый', ' прописавшемуся', ' перечиталось', ' читавшемся', ' перечитывавший', ' читавших', ' написывавшими', ' дочитавшего', ' почитывавшими', ' начитавшиеся', ' дочитаешься', ' читайте', ' прочитанный', ' писюльки', ' пишущее', ' синеющий', ' перечитавшихся', ' читая', ' дочитавший', ' написавшего', ' зачитывавшей', ' перечитываетесь', ' пишущая', ' пописанные', ' переписывались', ' прочитывавшим', ' переписывающего', ' дочитываемой', ' прописывающийся', ' пописывайте', ' пиша', ' написанное', ' написанная', ' почитавшего', ' писавшею', ' зачитавшеюся', ' переписанная', ' пропишете', ' прописываемой', ' подписавший', ' написываемыми', ' прочитавшими', ' письками', ' прочитывающийся', ' перечитаны', ' подпишете', ' подписываемое', ' почитавшемуся', ' дочитавшемся', ' синевшей', ' написывавшись', ' писанный', ' начиталась', ' прописываема', ' зачитавшемуся', ' прописанная', ' написываемых', ' зачитывающею', ' зачитываемую', ' зачитывающего', ' почитаемым', ' прочитавшим', ' перечитываю', ' перечитывавшаяся', ' переписывающие', ' зачитаетесь', ' подписывавшим', ' писали', ' прочитывав', ' переписавший', ' прочитываемая', ' прописывались', ' дочитаемся', ' пописывающем', ' написан', ' пропишешь', ' перепишусь', ' зачитанным', ' зачитавшемся', ' переписались', ' читающий', ' прочитать', ' прочитайте', ' читаются', ' прочитывавшихся', ' прочитывавшем', ' переписывавшихся', ' перечитающимися', ' читающиеся', ' прописываемыми', ' дочитывавшимся', ' читанную', ' прописываемым', ' почитывающего', ' перечитаюсь', ' пропишется', ' писавши', ' зачитываются', '  ...

# %% [markdown]
# # **`Matvejev Word Shredder`** architecture

# %% [markdown]
# Наш токенизатор является модификацией над `cBPE`. Алгоритм функционирует **без учителя**. Мы реализовываем **кастомный функционал качества**, аппроксимирующмй морфемные разбиения в **хорошем датасете** (см. критерии выше). Его предстоит жадно максимизировать. Он включает:
#   *   **Pointwise Mutual Information (PMI)**. Одна из самых популярных в компьютерной лингвистике мер ассоциации, используется для выделения коллокаций. Измеряет взаимозависимость между двумя токенами, показывая, сколько информации один токен предоставляет о другом.
#   *   **T-score**. Также очень популярная мера ассоциации для выделения коллокаций. Используется нами для копенсации проблемы PMI к присвоению редким биграммам больших значений. T-score как бы говорит относительно таких биграмм: "Возможно стоит слить два этих токена в один, но у нас недостаточно доказательств, чтобы быть уверенными в том, что токены, получившие большое значение PMI действительно являются хорошими кандидатами на слияние!"
#   *   **Information Gain**. Используется как функционал качества при обучении классификатора, основанного на решающих деревьях. В нашем случае измеряет снижение неопределенности при слиянии двух совместно встречающихся токенов в один. Именна эта мера "чувствует" границы морфем.
#
# Чем больше значение этих мер, тем сильнее мы хотим слить 2 токена в 1.
#
#
# ---

# %% [markdown]
# Также рассчитываются:
#
#   *   **Нормализация на длину** токена-кандидата на слияние, в общих чертах повторяющая ту, что используется в алгоритме **BM-25**. Здесь вводится штраф за слишком длиные токены.
#   *   **Геометрическое среднее**. Считается дважды: 1) между **PMI** и **T-score**. Геометрическое среднее, в отличии от среднего арифметического, позволяет избавиться от случаев, когда большое значение одного члена и маленькое значение другого члена превращается в довольно большое значение после усреднения. Значения после геометрического усреднения не могут быть высокими, если один из членов имеет маленькое значение. Т.е. такая операция как бы показывает, что мы хотим одновременно растить и **PMI**, и **T-score** в первом случае, а также значения **нормализованной аггрегированной меры** и **Information Gain** во втором.
#
# ---

# %% [markdown]
# Помимо этого, мы используем некоторые **эвристики**, стабилизирующие обучение алгоритма:
#
#
# *   Пропускаем кандидатов на слияние, длина которых больше, чем установленный порог (дефолтно, 5)
# *   Пропускаем кандидатов на слияние, абсолютное значение длины которых отличается от корня из средней длины токена больше, чем на установленный порог (дефолтно, 2)
# *   **Штраф за длину** вычисляется как **корень из разности квадратов длин**: Из квадрата длины токена-кандидата на слияние вычитаем квадраты длин составляющих его токенов. И берём из получившегося числа квадратный корень. Так, токен-кандидат на слияние, допустим `abcd`, будет получать менее жёсткий штраф, если будет состоять из токенов длины 3 и 1 (`a` и `bcd` или `abc` и `d`), чем если бы он состоял из токенов длины 2 и 2 (`ab` и `cd`). **Объяснение:** На практике было замечено, что границы морфем чаще нарушались при слияниях второго типа, чем первого.
# *   Обучение останавливается, если значение функционала качества топ-пары равно 0.

# %%
def get_pairs(word: Tuple[str]
) -> Set[Tuple[str, str]]:
    """Getting unique pairs of word unigrams"""
    return set(pairwise(word))

def calc_merge_coef(
    bi_counts: Dict[Tuple[str, str], int],
    uni_counts: Dict[str, int],
    len_norm_factor: float = 2.0,
    log_base: int = 2,
    gap_threshold: float = 1.0,
    max_merge_len: int = 5,
    max_len_delta: int = 2,
    report: bool = True
) -> Dict[Tuple[str, str], float]:
    """Calculating the merge coefficient used in tokenizer"""
    merge_dict = {}
    square, root = 2, 0.5
    norm_agg_assoc = []
    if log_base <= 1:
      raise ValueError('Logarithm base should be above 1')

    # Compute the arithmetic mean of unigram lengths for
    # furhter use in length penalization formula
    n_unigrams, n_bigrams = sum(uni_counts.values()), sum(bi_counts.values())
    len_count_sum = sum(len(token) * count for token, count in uni_counts.items())
    avg_uni_len = len_count_sum / n_unigrams

    # Define a very small value to avoid ZeroDivisionError in some computations
    eps = 1e-24

    for bigram, bi_count in bi_counts.items():
      left, right = bigram

      # We won't penalize for space length in the left token
      L_len = max(len(left.lstrip()), 1)
      R_len = len(right)
      pair_len = L_len + R_len

      # Skip bigram and do not count merge coefficient if: 1) candidate length
      # is above max_merge_len or 2) the absolute difference between
      # candidate length and average unigram length is above max_len_delta
      if (pair_len > max_merge_len or
          abs(pair_len - (avg_uni_len ** root)) > max_len_delta):
        continue

      # Compute length penalty for further use
      sq_len_penalty = pair_len ** square - L_len ** square - R_len ** square

      # Calculate probabilities for further computations
      # Raise to a power 0.75 to avoid high PMI of rare unigram problem
      left_prob = uni_counts[left] / n_unigrams
      right_prob = uni_counts[right] ** 0.75 / n_unigrams ** 0.75
      bi_prob = bi_count / n_bigrams

      # Calculate T-score
      t_score = (
          (bi_count - (uni_counts[left] * right_prob)) /
          (bi_count ** root)
      )
      # Compute a part of PMI without taking a logarithm
      pre_pmi = bi_prob / (left_prob * right_prob)

      # Geometric mean of PMI and t-score.
      # Adding 1 to t-score for taking a logarithm
      assoc_agg = root * (
          log(max(eps, pre_pmi), log_base) +
          log(max(1 + eps, t_score + 1), log_base)
      )

      # Compute entropy of the next (merge candidate)
      # and previous (unigrams) state.
      H_bi = -bi_prob * log(bi_prob, log_base)
      H_unigrams = -right_prob * log(right_prob, log_base) - left_prob * log(left_prob, log_base)

      # Compute information gain
      info_gain = H_unigrams - H_bi

      # Use length penalization similar to BM-25 one
      relative_len_pen = (sq_len_penalty ** root) / avg_uni_len
      penalized_score = assoc_agg - log(log_base - len_norm_factor +
                                    len_norm_factor * relative_len_pen,
                                    log_base)

      # The sum of logarithms = the logarithm of multiplication
      merge_coef = max(penalized_score + info_gain, 0)

      # Add a merge coefficient of the bigram to the dictionary
      merge_dict[bigram] = merge_coef
      if report:
        print(bigram)
        print(f'{avg_uni_len=}; {sq_len_penalty=}; {relative_len_pen=:.3f}')
        print(f'{pre_pmi=:.3f}; {t_score=:.3f}')
        print(f'{assoc_agg=:.3f} before length penalty')
        print(f'{penalized_score=:.3f}')
        print(f'{H_bi=:.3f}; {H_unigrams=:.3f}; {info_gain=:.3f}')
        print(f'{merge_coef=:.3f}')
        print('=' * 50)
    if merge_dict and report:
      print(f'''MIN MAX VALS:
      {min(merge_dict.values()):.3f};
      {max(merge_dict.values()):.3f}''')
      print('=' * 50)
    return merge_dict

def recalculate_counts(words_by_tokens: Dict[Tuple[str, ...], int]
  ) -> Tuple[Dict[str, int], Dict[Tuple[str, str], int]]:
    """Recalculating unigram and bigram counts"""
    unigram_counts = Counter()
    bigram_counts = Counter()

    for word, count in words_by_tokens.items():
      word_len = len(word)
      for unigram in word:
        unigram_counts[unigram] += count

      for i in range(word_len - 1):
        bigram = (word[i], word[i + 1])
        bigram_counts[bigram] += count

    return unigram_counts, bigram_counts

# %%
def merge(
    merge_pair: Tuple[str, str],
    words_by_tokens: Dict[Tuple[str, ...], int],
    len_norm_factor: float = 2.0,
    log_base: int = 2,
    gap_threshold: float = 1.0,
    max_merge_len: int = 5,
    max_len_delta: int = 2
):
    """Merges a given pair of tokens and updates corresponding stats"""
    new_token = merge_pair[0] + merge_pair[1]
    updated_words = {}

    # Process each word containing the bigram
    for word, count in list(words_by_tokens.items()):
        # Skip words that don't contain the merge pair
        found = False
        for i in range(len(word) - 1):
            if (word[i], word[i + 1]) == merge_pair:
                found = True
                break
        if not found:
            continue

        # Remove original word
        del words_by_tokens[word]

        # Build new word with merged token
        new_word = []
        i = 0
        while i < len(word):
            if i < len(word) - 1 and (word[i], word[i + 1]) == merge_pair:
                new_word.append(new_token)
                i += 2
            else:
                new_word.append(word[i])
                i += 1

        # Add new version of word
        new_word_tup = tuple(new_word)
        words_by_tokens[new_word_tup] = words_by_tokens.get(new_word_tup, 0) + count

    # Recalculate all counts
    unigram_counts, bigram_counts = recalculate_counts(words_by_tokens)
    merge_info_dict = calc_merge_coef(bigram_counts, unigram_counts,
                                      len_norm_factor, log_base, gap_threshold,
                                      max_merge_len, max_len_delta)
    return merge_info_dict, words_by_tokens, unigram_counts, bigram_counts

# %%
def train(
    data: List[str],
    n_merges: int,
    special_tokens: List[str] = None,
    alphabet: Set[str] = None,
    len_norm_factor: float = 2.0,
    log_base: int = 2,
    gap_threshold: float = 1.0,
    max_merge_len: int = 5,
    max_len_delta: int = 2,
    stop_threshold: float = 2
):
    """Trains BPE tokenizer on the data passed"""
    if n_merges <= 0:
        raise ValueError("The number of merges should be greater than zero")
    special_tokens = special_tokens or []

    # Initialize vocabulary
    chars = sorted(list(alphabet))
    id2token = {idx: char for idx, char in enumerate(chars)}
    merges = []

    # Tokenize data and count words
    words_by_tokens = {}
    for sample in data:
        words = WHITESPACE_SPLITTER.findall(sample)
        for word in words:
            tokens = tuple(word)
            words_by_tokens[tokens] = words_by_tokens.get(tokens, 0) + 1

    # Calculate initial counts
    unigram_counts, bigram_counts = recalculate_counts(words_by_tokens)

    # Initial probabilities
    merge_info_dict = calc_merge_coef(bigram_counts, unigram_counts,
                                      len_norm_factor, log_base, gap_threshold,
                                      max_merge_len, max_len_delta)

    # Build vocabulary
    while len(id2token) < n_merges + len(set(alphabet)) + len(special_tokens):
        if not merge_info_dict:
            break

        # Select pair with highest merge coefficient
        top_pair = max(merge_info_dict, key=merge_info_dict.get)
        new_token = top_pair[0] + top_pair[1]
        top_merge_coef = merge_info_dict[top_pair]

        # Stop execution if top_pair merge coefficient
        # below the threshold or equals 0
        if stop_threshold and isinstance(stop_threshold, float) and \
        top_merge_coef <= stop_threshold or top_merge_coef == 0:
            break

        # Skip if token already exists
        if new_token in id2token.values():
            del merge_info_dict[top_pair]
            continue

        # Record merge
        id2token[len(id2token)] = new_token
        merges.append(top_pair)

        # Perform merge and get updated state
        merge_info_dict, words_by_tokens, unigram_counts, bigram_counts = merge(
            top_pair, words_by_tokens, len_norm_factor, log_base, gap_threshold,
            max_merge_len, max_len_delta
        )

    # Add special tokens
    for token in special_tokens:
        id2token[len(id2token)] = token

    return {token: idx for idx, token in id2token.items()}, merges, merge_info_dict

# %%
class MatvejevWordShredder:
    def __init__(self, vocab: Dict[str, int],
                 merges: List[Tuple[str, str]],
                 eos_token: str = "[EOS]"):
        if eos_token not in vocab:
            raise ValueError("EOS token missing from vocabulary")
        self.token2id = vocab
        self.id2token = {v: k for k, v in self.token2id.items()}
        self.eos_token = eos_token
        self.eos_token_id = vocab[eos_token]
        self.merges = merges
        self.bpe_ranks = {pair: i for i, pair in enumerate(merges)}
        self._vocab_tokens = sorted(vocab.keys(), key=len, reverse=True)

    @lru_cache(maxsize=10000)
    def bpe(self, token: str) -> Tuple[str]:
        if len(token) == 1:
            return (token,)

        word = list(token)
        while len(word) > 1:
            pairs = list(zip(word[:-1], word[1:]))
            bigram = min(
                pairs,
                key=lambda pair: self.bpe_ranks.get(pair, float('inf'))
            )
            if bigram not in self.bpe_ranks:
                break

            new_word = []
            i = 0
            while i < len(word):
                if i < len(word) - 1 and (word[i], word[i+1]) == bigram:
                    new_word.append(word[i] + word[i+1])
                    i += 2
                else:
                    new_word.append(word[i])
                    i += 1
            word = new_word
        return tuple(word)

    def encode(self, text: str, add_eos_token: bool = False) -> List[int]:
        token_ids = []
        words = WHITESPACE_SPLITTER.findall(text)
        for word in words:
            token_ids.extend(
                self.token2id[token]
                for token in self.bpe(word)
            )

        if add_eos_token:
            token_ids.append(self.eos_token_id)

        return token_ids

    def decode(self, token_ids: List[int]) -> str:
        return [self.id2token.get(t_id, "[UNK]") for t_id in token_ids]

    def push_to_hub(self, repo_id, *, private=None, token=None):
        api = HfApi()
        repo_id = api.create_repo(
            repo_id=repo_id,
            token=token,
            private=private,
            exist_ok=True
        ).repo_id

        with SoftTemporaryDirectory() as tmp:
            save_dir = Path(tmp) / repo_id
            save_dir.mkdir(parents=True)

            # Save vocabulary and merges
            (save_dir / "vocabulary.json").write_text(
                json.dumps(self.token2id, indent=2)
            )
            (save_dir / "merges.json").write_text(
                json.dumps({"merges": self.merges})
            )

            api.upload_folder(
                repo_id=repo_id,
                folder_path=save_dir,
                token=token
            )

    @classmethod
    def from_pretrained(cls, pretrained_model_name_or_path, *, token=None, **kwargs):
        if not os.path.isdir(pretrained_model_name_or_path):
            model_path = snapshot_download(
                repo_id=pretrained_model_name_or_path,
                token=token
            )
        else:
            model_path = pretrained_model_name_or_path

        model_path = Path(model_path)
        vocab = json.loads((model_path / "vocabulary.json").read_text())
        merges_data = json.loads((model_path / "merges.json").read_text())

        return cls(
            vocab,
            [tuple(pair) for pair in merges_data["merges"]],
            **kwargs
        )

# %% [markdown]
# # Results & Metrics

# %%
# The number of alphabet symbols
len(set(ALPHABET))
# Out:
# 109

# %%
# Explicitly place default values as input
vocab, merges, merge_dict = train(toy_data,
                                  n_merges=116,
                                  special_tokens=['[EOS]'],
                                  alphabet=ALPHABET,
                                  len_norm_factor=2.0,
                                  log_base=2,
                                  gap_threshold=1.0,
                                  max_merge_len=5,
                                  max_len_delta=2,
                                  stop_threshold=2)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# penalized_score=0.879
# H_bi=0.002; H_unigrams=0.112; info_gain=0.111
# merge_coef=0.989
# ==================================================
# ('нн', 'и')
# avg_uni_len=2.5419204222492895; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=5.426; t_score=0.767
# assoc_agg=1.631 before length penalty
# penalized_score=0.977
# H_bi=0.002; H_unigrams=0.104; info_gain=0.102
# merge_coef=1.079
# ==================================================
# ('а', 'ла')
# avg_uni_len=2.5419204222492895; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=4.311; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.467
# H_bi=0.025; H_unigrams=0.287; info_gain=0.263
# merge_coef=1.730
# ==================================================
# ('е', 'ла')
# avg_uni_len=2.5419204222492895; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.847; t_score=0.316
# assoc_agg=0.641 before length penalty
# penalized_score=-0.014
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.116
# ==================================================
# ('ан', 'а')
# avg_uni_len=2.5419204222492895; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=6.931; t_score=2.712
# assoc_agg=2.343 before length penalty
# penalized_score=1.689
# H_bi=0.013; H_unigrams=0.335; info_gain=0.321
# merge_coef=2.010
# ==================================================
# MIN MAX VALS:
#       0.000;
#       2.791
# ==================================================
# ('а', 'л')
# avg_uni_len=2.5421784590396914; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=4.310; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.967
# H_bi=0.025; H_unigrams=0.288; info_gain=0.263
# merge_coef=2.230
# ==================================================
# ('а', 'ю')
# avg_uni_len=2.5421784590396914; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=2.319; t_score=1.115
# assoc_agg=1.147 before length penalty
# penalized_score=0.993
# H_bi=0.008; H_unigrams=0.245; info_gain=0.237
# merge_coef=1.230
# ==================================================
# ('а', 'в')
# avg_uni_len=2.5421784590396914; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=3.533; t_score=2.225
# assoc_agg=1.755 before length penalty
# penalized_score=1.601
# H_bi=0.014; H_unigrams=0.259; info_gain=0.244
# merge_coef=1.845
# ==================================================
# ('а', 'й')
# avg_uni_len=2.5421784590396914; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=3.059; t_score=2.117
# assoc_agg=1.627 before length penalty
# penalized_score=1.473
# H_bi=0.015; H_unigrams=0.272; info_gain=0.256
# merge_coef=1.729
# ==================================================
# ('й', 'ся')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=5.222; t_score=2.936
# assoc_agg=2.181 before length penalty
# penalized_score=1.527
# H_bi=0.017; H_unigrams=0.388; info_gain=0.371
# merge_coef=1.898
# ==================================================
# ('л', 'ся')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=4.883; t_score=3.231
# assoc_agg=2.184 before length penalty
# penalized_score=1.530
# H_bi=0.021; H_unigrams=0.396; info_gain=0.375
# merge_coef=1.905
# ==================================================
# ('а', 'ть')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=4.310; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.467
# H_bi=0.025; H_unigrams=0.288; info_gain=0.263
# merge_coef=1.730
# ==================================================
# ('а', 'ющ')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=3.151; t_score=5.291
# assoc_agg=2.154 before length penalty
# penalized_score=1.501
# H_bi=0.066; H_unigrams=0.475; info_gain=0.408
# merge_coef=1.909
# ==================================================
# ('вш', 'и')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=3.590; t_score=2.149
# assoc_agg=1.750 before length penalty
# penalized_score=1.096
# H_bi=0.013; H_unigrams=0.230; info_gain=0.216
# merge_coef=1.312
# ==================================================
# ('я', 'сь')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=10.159; t_score=2.477
# assoc_agg=2.571 before length penalty
# penalized_score=1.917
# H_bi=0.010; H_unigrams=0.203; info_gain=0.193
# merge_coef=2.110
# ==================================================
# ('у', 'сь')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=13.207; t_score=1.809
# assoc_agg=2.607 before length penalty
# penalized_score=1.953
# H_bi=0.006; H_unigrams=0.190; info_gain=0.185
# merge_coef=2.137
# ==================================================
# ('ся', 'м')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.566; t_score=0.273
# assoc_agg=0.498 before length penalty
# penalized_score=-0.156
# H_bi=0.003; H_unigrams=0.260; info_gain=0.257
# merge_coef=0.101
# ==================================================
# ('ся', 'х')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.566; t_score=0.273
# assoc_agg=0.498 before length penalty
# penalized_score=-0.156
# H_bi=0.003; H_unigrams=0.260; info_gain=0.257
# merge_coef=0.101
# ==================================================
# ('а', 'сь')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=0.163; t_score=-9.516
# assoc_agg=-1.307 before length penalty
# penalized_score=-1.960
# H_bi=0.003; H_unigrams=0.369; info_gain=0.366
# merge_coef=0.000
# ==================================================
# ('а', 'ем')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=2.120; t_score=2.914
# assoc_agg=1.526 before length penalty
# penalized_score=0.872
# H_bi=0.048; H_unigrams=0.473; info_gain=0.425
# merge_coef=1.297
# ==================================================
# ('ем', 'а')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=0.518; t_score=-4.981
# assoc_agg=-0.474 before length penalty
# penalized_score=-1.128
# H_bi=0.014; H_unigrams=0.476; info_gain=0.462
# merge_coef=0.000
# ==================================================
# ('ем', 'ы')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=7.243; t_score=2.860
# assoc_agg=2.403 before length penalty
# penalized_score=1.749
# H_bi=0.014; H_unigrams=0.208; info_gain=0.194
# merge_coef=1.943
# ==================================================
# ('ем', 'о')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=7.243; t_score=2.860
# assoc_agg=2.403 before length penalty
# penalized_score=1.749
# H_bi=0.014; H_unigrams=0.208; info_gain=0.194
# merge_coef=1.943
# ==================================================
# ('е', 'я')
# avg_uni_len=2.5421784590396914; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=2.646; t_score=0.523
# assoc_agg=1.005 before length penalty
# penalized_score=0.851
# H_bi=0.002; H_unigrams=0.108; info_gain=0.106
# merge_coef=0.957
# ==================================================
# ('я', 'я')
# avg_uni_len=2.5421784590396914; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=8.345; t_score=1.200
# assoc_agg=2.099 before length penalty
# penalized_score=1.945
# H_bi=0.003; H_unigrams=0.097; info_gain=0.094
# merge_coef=2.040
# ==================================================
# ('е', 'в')
# avg_uni_len=2.5421784590396914; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=2.901; t_score=0.565
# assoc_agg=1.091 before length penalty
# penalized_score=0.937
# H_bi=0.002; H_unigrams=0.103; info_gain=0.101
# merge_coef=1.038
# ==================================================
# ('е', 'л')
# avg_uni_len=2.5421784590396914; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=1.847; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=0.487
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.616
# ==================================================
# ('е', 'вш')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=6.476; t_score=3.012
# assoc_agg=2.350 before length penalty
# penalized_score=1.696
# H_bi=0.016; H_unigrams=0.293; info_gain=0.277
# merge_coef=1.973
# ==================================================
# ('ьк', 'а')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=6.931; t_score=2.313
# assoc_agg=2.261 before length penalty
# penalized_score=1.607
# H_bi=0.010; H_unigrams=0.330; info_gain=0.320
# merge_coef=1.926
# ==================================================
# ('а', 'м')
# avg_uni_len=2.5421784590396914; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=2.186; t_score=0.597
# assoc_agg=0.902 before length penalty
# penalized_score=0.748
# H_bi=0.003; H_unigrams=0.213; info_gain=0.210
# merge_coef=0.958
# ==================================================
# ('ьк', 'и')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=10.851; t_score=1.250
# assoc_agg=2.305 before length penalty
# penalized_score=1.651
# H_bi=0.003; H_unigrams=0.104; info_gain=0.101
# merge_coef=1.752
# ==================================================
# ('а', 'х')
# avg_uni_len=2.5421784590396914; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=2.186; t_score=0.597
# assoc_agg=0.902 before length penalty
# penalized_score=0.748
# H_bi=0.003; H_unigrams=0.213; info_gain=0.210
# merge_coef=0.958
# ==================================================
# ('ьк', 'е')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=9.637; t_score=1.229
# assoc_agg=2.212 before length penalty
# penalized_score=1.558
# H_bi=0.003; H_unigrams=0.112; info_gain=0.109
# merge_coef=1.668
# ==================================================
# ('е', 'ть')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.847; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=-0.013
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.116
# ==================================================
# ('е', 'ющ')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=5.174; t_score=2.725
# assoc_agg=2.134 before length penalty
# penalized_score=1.480
# H_bi=0.015; H_unigrams=0.319; info_gain=0.303
# merge_coef=1.784
# ==================================================
# ('е', 'ем')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=0.402; t_score=-2.145
# assoc_agg=-0.658 before length penalty
# penalized_score=-1.312
# H_bi=0.002; H_unigrams=0.317; info_gain=0.315
# merge_coef=0.000
# ==================================================
# ('а', 'ют')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=2.987; t_score=2.081
# assoc_agg=1.601 before length penalty
# penalized_score=0.947
# H_bi=0.015; H_unigrams=0.273; info_gain=0.258
# merge_coef=1.205
# ==================================================
# ('е', 'ют')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=2.264; t_score=0.442
# assoc_agg=0.854 before length penalty
# penalized_score=0.200
# H_bi=0.002; H_unigrams=0.117; info_gain=0.116
# merge_coef=0.315
# ==================================================
# ('а', 'ло')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=4.310; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.467
# H_bi=0.025; H_unigrams=0.288; info_gain=0.263
# merge_coef=1.730
# ==================================================
# ('е', 'ло')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.847; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=-0.013
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.116
# ==================================================
# ('а', 'ны')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=5.631; t_score=2.573
# assoc_agg=2.165 before length penalty
# penalized_score=1.511
# H_bi=0.013; H_unigrams=0.234; info_gain=0.221
# merge_coef=1.732
# ==================================================
# ('а', 'ли')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=4.310; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.467
# H_bi=0.025; H_unigrams=0.288; info_gain=0.263
# merge_coef=1.730
# ==================================================
# ('е', 'ли')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.847; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=-0.013
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.116
# ==================================================
# ('я', 'ми')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=10.100; t_score=0.875
# assoc_agg=2.122 before length penalty
# penalized_score=1.468
# H_bi=0.002; H_unigrams=0.060; info_gain=0.058
# merge_coef=1.526
# ==================================================
# ('а', 'ми')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.300; t_score=0.040
# assoc_agg=0.217 before length penalty
# penalized_score=-0.436
# H_bi=0.003; H_unigrams=0.226; info_gain=0.223
# merge_coef=0.000
# ==================================================
# ('к', 'ою')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=52.730; t_score=1.380
# assoc_agg=3.486 before length penalty
# penalized_score=2.832
# H_bi=0.003; H_unigrams=0.081; info_gain=0.078
# merge_coef=2.910
# ==================================================
# ('сь', 'к')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=6.955; t_score=1.157
# assoc_agg=1.954 before length penalty
# penalized_score=1.300
# H_bi=0.003; H_unigrams=0.105; info_gain=0.102
# merge_coef=1.402
# ==================================================
# ('к', 'ой')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=52.730; t_score=1.380
# assoc_agg=3.486 before length penalty
# penalized_score=2.832
# H_bi=0.003; H_unigrams=0.081; info_gain=0.078
# merge_coef=2.910
# ==================================================
# ('а', 'но')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=5.631; t_score=2.573
# assoc_agg=2.165 before length penalty
# penalized_score=1.511
# H_bi=0.013; H_unigrams=0.234; info_gain=0.221
# merge_coef=1.732
# ==================================================
# ('а', 'ет')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=2.436; t_score=1.736
# assoc_agg=1.368 before length penalty
# penalized_score=0.714
# H_bi=0.015; H_unigrams=0.288; info_gain=0.272
# merge_coef=0.987
# ==================================================
# ('е', 'ет')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.847; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=-0.013
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.116
# ==================================================
# ('нн', 'я')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=13.561; t_score=1.282
# assoc_agg=2.476 before length penalty
# penalized_score=1.822
# H_bi=0.003; H_unigrams=0.090; info_gain=0.087
# merge_coef=1.909
# ==================================================
# ('нн', 'е')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=4.818; t_score=0.738
# assoc_agg=1.533 before length penalty
# penalized_score=0.879
# H_bi=0.002; H_unigrams=0.112; info_gain=0.111
# merge_coef=0.990
# ==================================================
# ('нн', 'и')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=5.425; t_score=0.767
# assoc_agg=1.631 before length penalty
# penalized_score=0.977
# H_bi=0.002; H_unigrams=0.104; info_gain=0.102
# merge_coef=1.079
# ==================================================
# ('а', 'ла')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=4.310; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.467
# H_bi=0.025; H_unigrams=0.288; info_gain=0.263
# merge_coef=1.730
# ==================================================
# ('е', 'ла')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.847; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=-0.013
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.116
# ==================================================
# ('ан', 'а')
# avg_uni_len=2.5421784590396914; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=6.931; t_score=2.712
# assoc_agg=2.343 before length penalty
# penalized_score=1.689
# H_bi=0.013; H_unigrams=0.335; info_gain=0.321
# merge_coef=2.010
# ==================================================
# MIN MAX VALS:
#       0.000;
#       2.910
# ==================================================
# ('а', 'л')
# avg_uni_len=2.542694689816225; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=4.310; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.967
# H_bi=0.025; H_unigrams=0.288; info_gain=0.263
# merge_coef=2.230
# ==================================================
# ('а', 'ю')
# avg_uni_len=2.542694689816225; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=2.319; t_score=1.115
# assoc_agg=1.147 before length penalty
# penalized_score=0.993
# H_bi=0.008; H_unigrams=0.245; info_gain=0.237
# merge_coef=1.231
# ==================================================
# ('а', 'в')
# avg_uni_len=2.542694689816225; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=3.532; t_score=2.225
# assoc_agg=1.755 before length penalty
# penalized_score=1.601
# H_bi=0.014; H_unigrams=0.259; info_gain=0.244
# merge_coef=1.846
# ==================================================
# ('а', 'й')
# avg_uni_len=2.542694689816225; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=3.059; t_score=2.117
# assoc_agg=1.627 before length penalty
# penalized_score=1.473
# H_bi=0.015; H_unigrams=0.272; info_gain=0.256
# merge_coef=1.729
# ==================================================
# ('й', 'ся')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=5.222; t_score=2.936
# assoc_agg=2.181 before length penalty
# penalized_score=1.527
# H_bi=0.017; H_unigrams=0.388; info_gain=0.371
# merge_coef=1.898
# ==================================================
# ('л', 'ся')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=4.882; t_score=3.231
# assoc_agg=2.184 before length penalty
# penalized_score=1.531
# H_bi=0.021; H_unigrams=0.396; info_gain=0.375
# merge_coef=1.905
# ==================================================
# ('а', 'ть')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=4.310; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.467
# H_bi=0.025; H_unigrams=0.288; info_gain=0.263
# merge_coef=1.730
# ==================================================
# ('а', 'ющ')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=3.150; t_score=5.290
# assoc_agg=2.154 before length penalty
# penalized_score=1.501
# H_bi=0.066; H_unigrams=0.475; info_gain=0.408
# merge_coef=1.909
# ==================================================
# ('вш', 'и')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=3.589; t_score=2.149
# assoc_agg=1.749 before length penalty
# penalized_score=1.096
# H_bi=0.013; H_unigrams=0.230; info_gain=0.216
# merge_coef=1.312
# ==================================================
# ('я', 'сь')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=10.158; t_score=2.477
# assoc_agg=2.571 before length penalty
# penalized_score=1.918
# H_bi=0.010; H_unigrams=0.203; info_gain=0.193
# merge_coef=2.110
# ==================================================
# ('у', 'сь')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=13.206; t_score=1.809
# assoc_agg=2.607 before length penalty
# penalized_score=1.953
# H_bi=0.006; H_unigrams=0.190; info_gain=0.185
# merge_coef=2.137
# ==================================================
# ('ся', 'м')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.566; t_score=0.273
# assoc_agg=0.498 before length penalty
# penalized_score=-0.156
# H_bi=0.003; H_unigrams=0.260; info_gain=0.257
# merge_coef=0.102
# ==================================================
# ('ся', 'х')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.566; t_score=0.273
# assoc_agg=0.498 before length penalty
# penalized_score=-0.156
# H_bi=0.003; H_unigrams=0.260; info_gain=0.257
# merge_coef=0.102
# ==================================================
# ('а', 'сь')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=0.163; t_score=-9.517
# assoc_agg=-1.307 before length penalty
# penalized_score=-1.960
# H_bi=0.003; H_unigrams=0.369; info_gain=0.366
# merge_coef=0.000
# ==================================================
# ('а', 'ем')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=2.120; t_score=2.914
# assoc_agg=1.526 before length penalty
# penalized_score=0.873
# H_bi=0.048; H_unigrams=0.473; info_gain=0.425
# merge_coef=1.298
# ==================================================
# ('ем', 'а')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=0.518; t_score=-4.982
# assoc_agg=-0.474 before length penalty
# penalized_score=-1.128
# H_bi=0.014; H_unigrams=0.476; info_gain=0.462
# merge_coef=0.000
# ==================================================
# ('ем', 'ы')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=7.242; t_score=2.860
# assoc_agg=2.402 before length penalty
# penalized_score=1.749
# H_bi=0.014; H_unigrams=0.208; info_gain=0.194
# merge_coef=1.943
# ==================================================
# ('ем', 'о')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=7.242; t_score=2.860
# assoc_agg=2.402 before length penalty
# penalized_score=1.749
# H_bi=0.014; H_unigrams=0.208; info_gain=0.194
# merge_coef=1.943
# ==================================================
# ('е', 'я')
# avg_uni_len=2.542694689816225; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=2.646; t_score=0.523
# assoc_agg=1.005 before length penalty
# penalized_score=0.851
# H_bi=0.002; H_unigrams=0.108; info_gain=0.106
# merge_coef=0.958
# ==================================================
# ('я', 'я')
# avg_uni_len=2.542694689816225; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=8.344; t_score=1.200
# assoc_agg=2.099 before length penalty
# penalized_score=1.946
# H_bi=0.003; H_unigrams=0.097; info_gain=0.094
# merge_coef=2.040
# ==================================================
# ('е', 'в')
# avg_uni_len=2.542694689816225; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=2.901; t_score=0.564
# assoc_agg=1.091 before length penalty
# penalized_score=0.937
# H_bi=0.002; H_unigrams=0.103; info_gain=0.101
# merge_coef=1.038
# ==================================================
# ('е', 'л')
# avg_uni_len=2.542694689816225; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=1.846; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=0.487
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.617
# ==================================================
# ('е', 'вш')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=6.475; t_score=3.012
# assoc_agg=2.350 before length penalty
# penalized_score=1.696
# H_bi=0.016; H_unigrams=0.293; info_gain=0.277
# merge_coef=1.973
# ==================================================
# ('ьк', 'а')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=6.930; t_score=2.313
# assoc_agg=2.260 before length penalty
# penalized_score=1.607
# H_bi=0.010; H_unigrams=0.330; info_gain=0.320
# merge_coef=1.927
# ==================================================
# ('а', 'м')
# avg_uni_len=2.542694689816225; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=2.186; t_score=0.597
# assoc_agg=0.902 before length penalty
# penalized_score=0.748
# H_bi=0.003; H_unigrams=0.213; info_gain=0.210
# merge_coef=0.958
# ==================================================
# ('ьк', 'и')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=10.850; t_score=1.250
# assoc_agg=2.305 before length penalty
# penalized_score=1.651
# H_bi=0.003; H_unigrams=0.104; info_gain=0.101
# merge_coef=1.752
# ==================================================
# ('а', 'х')
# avg_uni_len=2.542694689816225; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=2.186; t_score=0.597
# assoc_agg=0.902 before length penalty
# penalized_score=0.748
# H_bi=0.003; H_unigrams=0.213; info_gain=0.210
# merge_coef=0.958
# ==================================================
# ('ьк', 'е')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=9.636; t_score=1.229
# assoc_agg=2.212 before length penalty
# penalized_score=1.559
# H_bi=0.003; H_unigrams=0.112; info_gain=0.109
# merge_coef=1.668
# ==================================================
# ('е', 'ть')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.846; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=-0.013
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.117
# ==================================================
# ('е', 'ющ')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=5.174; t_score=2.725
# assoc_agg=2.134 before length penalty
# penalized_score=1.481
# H_bi=0.015; H_unigrams=0.319; info_gain=0.303
# merge_coef=1.784
# ==================================================
# ('е', 'ем')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=0.402; t_score=-2.145
# assoc_agg=-0.658 before length penalty
# penalized_score=-1.312
# H_bi=0.002; H_unigrams=0.317; info_gain=0.315
# merge_coef=0.000
# ==================================================
# ('а', 'ют')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=2.987; t_score=2.081
# assoc_agg=1.601 before length penalty
# penalized_score=0.947
# H_bi=0.015; H_unigrams=0.273; info_gain=0.258
# merge_coef=1.205
# ==================================================
# ('е', 'ют')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=2.264; t_score=0.442
# assoc_agg=0.854 before length penalty
# penalized_score=0.200
# H_bi=0.002; H_unigrams=0.117; info_gain=0.116
# merge_coef=0.316
# ==================================================
# ('а', 'ло')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=4.310; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.467
# H_bi=0.025; H_unigrams=0.288; info_gain=0.263
# merge_coef=1.730
# ==================================================
# ('е', 'ло')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.846; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=-0.013
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.117
# ==================================================
# ('а', 'ны')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=5.630; t_score=2.572
# assoc_agg=2.165 before length penalty
# penalized_score=1.511
# H_bi=0.013; H_unigrams=0.234; info_gain=0.221
# merge_coef=1.732
# ==================================================
# ('а', 'ли')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=4.310; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.467
# H_bi=0.025; H_unigrams=0.288; info_gain=0.263
# merge_coef=1.730
# ==================================================
# ('е', 'ли')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.846; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=-0.013
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.117
# ==================================================
# ('я', 'ми')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=10.099; t_score=0.875
# assoc_agg=2.121 before length penalty
# penalized_score=1.468
# H_bi=0.002; H_unigrams=0.060; info_gain=0.058
# merge_coef=1.526
# ==================================================
# ('а', 'ми')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.300; t_score=0.040
# assoc_agg=0.217 before length penalty
# penalized_score=-0.436
# H_bi=0.003; H_unigrams=0.226; info_gain=0.223
# merge_coef=0.000
# ==================================================
# ('к', 'ой')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=105.449; t_score=1.397
# assoc_agg=3.991 before length penalty
# penalized_score=3.337
# H_bi=0.003; H_unigrams=0.079; info_gain=0.076
# merge_coef=3.413
# ==================================================
# ('сь', 'к')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=5.848; t_score=0.784
# assoc_agg=1.691 before length penalty
# penalized_score=1.038
# H_bi=0.002; H_unigrams=0.097; info_gain=0.095
# merge_coef=1.133
# ==================================================
# ('а', 'но')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=5.630; t_score=2.572
# assoc_agg=2.165 before length penalty
# penalized_score=1.511
# H_bi=0.013; H_unigrams=0.234; info_gain=0.221
# merge_coef=1.732
# ==================================================
# ('а', 'ет')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=2.436; t_score=1.736
# assoc_agg=1.368 before length penalty
# penalized_score=0.715
# H_bi=0.015; H_unigrams=0.288; info_gain=0.272
# merge_coef=0.987
# ==================================================
# ('е', 'ет')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.846; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=-0.013
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.117
# ==================================================
# ('нн', 'я')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=13.560; t_score=1.282
# assoc_agg=2.476 before length penalty
# penalized_score=1.822
# H_bi=0.003; H_unigrams=0.090; info_gain=0.087
# merge_coef=1.909
# ==================================================
# ('нн', 'е')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=4.818; t_score=0.738
# assoc_agg=1.533 before length penalty
# penalized_score=0.879
# H_bi=0.002; H_unigrams=0.112; info_gain=0.111
# merge_coef=0.990
# ==================================================
# ('нн', 'и')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=5.425; t_score=0.767
# assoc_agg=1.631 before length penalty
# penalized_score=0.977
# H_bi=0.002; H_unigrams=0.104; info_gain=0.102
# merge_coef=1.079
# ==================================================
# ('а', 'ла')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=4.310; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.467
# H_bi=0.025; H_unigrams=0.288; info_gain=0.263
# merge_coef=1.730
# ==================================================
# ('е', 'ла')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=1.846; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=-0.013
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.117
# ==================================================
# ('ан', 'а')
# avg_uni_len=2.542694689816225; sq_len_penalty=4; relative_len_pen=0.787
# pre_pmi=6.930; t_score=2.712
# assoc_agg=2.343 before length penalty
# penalized_score=1.689
# H_bi=0.013; H_unigrams=0.335; info_gain=0.321
# merge_coef=2.010
# ==================================================
# MIN MAX VALS:
#       0.000;
#       3.413
# ==================================================
# ('а', 'л')
# avg_uni_len=2.5432111302934906; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=4.310; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.968
# H_bi=0.025; H_unigrams=0.288; info_gain=0.263
# merge_coef=2.230
# ==================================================
# ('а', 'ю')
# avg_uni_len=2.5432111302934906; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=2.318; t_score=1.115
# assoc_agg=1.147 before length penalty
# penalized_score=0.993
# H_bi=0.008; H_unigrams=0.245; info_gain=0.237
# merge_coef=1.231
# ==================================================
# ('а', 'в')
# avg_uni_len=2.5432111302934906; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=3.532; t_score=2.225
# assoc_agg=1.755 before length penalty
# penalized_score=1.602
# H_bi=0.014; H_unigrams=0.259; info_gain=0.244
# merge_coef=1.846
# ==================================================
# ('а', 'й')
# avg_uni_len=2.5432111302934906; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=3.059; t_score=2.116
# assoc_agg=1.626 before length penalty
# penalized_score=1.473
# H_bi=0.015; H_unigrams=0.272; info_gain=0.256
# merge_coef=1.730
# ==================================================
# ('й', 'ся')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=5.221; t_score=2.936
# assoc_agg=2.181 before length penalty
# penalized_score=1.527
# H_bi=0.017; H_unigrams=0.388; info_gain=0.371
# merge_coef=1.898
# ==================================================
# ('л', 'ся')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=4.882; t_score=3.231
# assoc_agg=2.184 before length penalty
# penalized_score=1.531
# H_bi=0.021; H_unigrams=0.396; info_gain=0.375
# merge_coef=1.906
# ==================================================
# ('а', 'ть')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=4.310; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.468
# H_bi=0.025; H_unigrams=0.288; info_gain=0.263
# merge_coef=1.730
# ==================================================
# ('а', 'ющ')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=3.150; t_score=5.290
# assoc_agg=2.154 before length penalty
# penalized_score=1.501
# H_bi=0.066; H_unigrams=0.475; info_gain=0.408
# merge_coef=1.909
# ==================================================
# ('вш', 'и')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=3.589; t_score=2.149
# assoc_agg=1.749 before length penalty
# penalized_score=1.096
# H_bi=0.013; H_unigrams=0.230; info_gain=0.216
# merge_coef=1.312
# ==================================================
# ('я', 'сь')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=10.157; t_score=2.477
# assoc_agg=2.571 before length penalty
# penalized_score=1.918
# H_bi=0.010; H_unigrams=0.203; info_gain=0.193
# merge_coef=2.110
# ==================================================
# ('у', 'сь')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=13.205; t_score=1.809
# assoc_agg=2.606 before length penalty
# penalized_score=1.953
# H_bi=0.006; H_unigrams=0.190; info_gain=0.185
# merge_coef=2.138
# ==================================================
# ('ся', 'м')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=1.566; t_score=0.273
# assoc_agg=0.498 before length penalty
# penalized_score=-0.156
# H_bi=0.003; H_unigrams=0.260; info_gain=0.257
# merge_coef=0.102
# ==================================================
# ('ся', 'х')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=1.566; t_score=0.273
# assoc_agg=0.498 before length penalty
# penalized_score=-0.156
# H_bi=0.003; H_unigrams=0.260; info_gain=0.257
# merge_coef=0.102
# ==================================================
# ('а', 'сь')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=0.163; t_score=-9.519
# assoc_agg=-1.307 before length penalty
# penalized_score=-1.960
# H_bi=0.003; H_unigrams=0.369; info_gain=0.366
# merge_coef=0.000
# ==================================================
# ('а', 'ем')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=2.120; t_score=2.913
# assoc_agg=1.526 before length penalty
# penalized_score=0.873
# H_bi=0.048; H_unigrams=0.473; info_gain=0.425
# merge_coef=1.298
# ==================================================
# ('ем', 'а')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=0.518; t_score=-4.983
# assoc_agg=-0.474 before length penalty
# penalized_score=-1.128
# H_bi=0.014; H_unigrams=0.476; info_gain=0.462
# merge_coef=0.000
# ==================================================
# ('ем', 'ы')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=7.241; t_score=2.860
# assoc_agg=2.402 before length penalty
# penalized_score=1.749
# H_bi=0.014; H_unigrams=0.208; info_gain=0.194
# merge_coef=1.943
# ==================================================
# ('ем', 'о')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=7.241; t_score=2.860
# assoc_agg=2.402 before length penalty
# penalized_score=1.749
# H_bi=0.014; H_unigrams=0.208; info_gain=0.194
# merge_coef=1.943
# ==================================================
# ('е', 'я')
# avg_uni_len=2.5432111302934906; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=2.645; t_score=0.522
# assoc_agg=1.005 before length penalty
# penalized_score=0.852
# H_bi=0.002; H_unigrams=0.108; info_gain=0.106
# merge_coef=0.958
# ==================================================
# ('я', 'я')
# avg_uni_len=2.5432111302934906; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=8.343; t_score=1.200
# assoc_agg=2.099 before length penalty
# penalized_score=1.946
# H_bi=0.003; H_unigrams=0.097; info_gain=0.094
# merge_coef=2.040
# ==================================================
# ('е', 'в')
# avg_uni_len=2.5432111302934906; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=2.900; t_score=0.564
# assoc_agg=1.091 before length penalty
# penalized_score=0.938
# H_bi=0.002; H_unigrams=0.103; info_gain=0.101
# merge_coef=1.038
# ==================================================
# ('е', 'л')
# avg_uni_len=2.5432111302934906; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=1.846; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=0.487
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.617
# ==================================================
# ('е', 'вш')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=6.474; t_score=3.012
# assoc_agg=2.349 before length penalty
# penalized_score=1.696
# H_bi=0.016; H_unigrams=0.293; info_gain=0.277
# merge_coef=1.973
# ==================================================
# ('ьк', 'а')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=6.930; t_score=2.313
# assoc_agg=2.260 before length penalty
# penalized_score=1.607
# H_bi=0.010; H_unigrams=0.330; info_gain=0.320
# merge_coef=1.927
# ==================================================
# ('а', 'м')
# avg_uni_len=2.5432111302934906; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=2.186; t_score=0.597
# assoc_agg=0.902 before length penalty
# penalized_score=0.748
# H_bi=0.003; H_unigrams=0.213; info_gain=0.210
# merge_coef=0.958
# ==================================================
# ('ьк', 'и')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=10.849; t_score=1.250
# assoc_agg=2.305 before length penalty
# penalized_score=1.651
# H_bi=0.003; H_unigrams=0.104; info_gain=0.101
# merge_coef=1.752
# ==================================================
# ('а', 'х')
# avg_uni_len=2.5432111302934906; sq_len_penalty=2; relative_len_pen=0.556
# pre_pmi=2.186; t_score=0.597
# assoc_agg=0.902 before length penalty
# penalized_score=0.748
# H_bi=0.003; H_unigrams=0.213; info_gain=0.210
# merge_coef=0.958
# ==================================================
# ('ьк', 'е')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=9.635; t_score=1.229
# assoc_agg=2.212 before length penalty
# penalized_score=1.559
# H_bi=0.003; H_unigrams=0.112; info_gain=0.109
# merge_coef=1.668
# ==================================================
# ('е', 'ть')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=1.846; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=-0.013
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.117
# ==================================================
# ('е', 'ющ')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=5.173; t_score=2.725
# assoc_agg=2.134 before length penalty
# penalized_score=1.481
# H_bi=0.015; H_unigrams=0.319; info_gain=0.303
# merge_coef=1.784
# ==================================================
# ('е', 'ем')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=0.402; t_score=-2.145
# assoc_agg=-0.658 before length penalty
# penalized_score=-1.311
# H_bi=0.002; H_unigrams=0.317; info_gain=0.315
# merge_coef=0.000
# ==================================================
# ('а', 'ют')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=2.987; t_score=2.080
# assoc_agg=1.601 before length penalty
# penalized_score=0.948
# H_bi=0.015; H_unigrams=0.273; info_gain=0.258
# merge_coef=1.206
# ==================================================
# ('е', 'ют')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=2.264; t_score=0.442
# assoc_agg=0.853 before length penalty
# penalized_score=0.200
# H_bi=0.002; H_unigrams=0.117; info_gain=0.116
# merge_coef=0.316
# ==================================================
# ('а', 'ло')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=4.310; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.468
# H_bi=0.025; H_unigrams=0.288; info_gain=0.263
# merge_coef=1.730
# ==================================================
# ('е', 'ло')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=1.846; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=-0.013
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.117
# ==================================================
# ('а', 'ны')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=5.630; t_score=2.572
# assoc_agg=2.165 before length penalty
# penalized_score=1.512
# H_bi=0.013; H_unigrams=0.234; info_gain=0.221
# merge_coef=1.732
# ==================================================
# ('а', 'ли')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=4.310; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.468
# H_bi=0.025; H_unigrams=0.288; info_gain=0.263
# merge_coef=1.730
# ==================================================
# ('е', 'ли')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=1.846; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=-0.013
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.117
# ==================================================
# ('я', 'ми')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=10.098; t_score=0.875
# assoc_agg=2.121 before length penalty
# penalized_score=1.468
# H_bi=0.002; H_unigrams=0.060; info_gain=0.058
# merge_coef=1.526
# ==================================================
# ('а', 'ми')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=1.300; t_score=0.040
# assoc_agg=0.217 before length penalty
# penalized_score=-0.436
# H_bi=0.003; H_unigrams=0.226; info_gain=0.223
# merge_coef=0.000
# ==================================================
# ('а', 'но')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=5.630; t_score=2.572
# assoc_agg=2.165 before length penalty
# penalized_score=1.512
# H_bi=0.013; H_unigrams=0.234; info_gain=0.221
# merge_coef=1.732
# ==================================================
# ('а', 'ет')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=2.436; t_score=1.735
# assoc_agg=1.368 before length penalty
# penalized_score=0.715
# H_bi=0.015; H_unigrams=0.288; info_gain=0.272
# merge_coef=0.987
# ==================================================
# ('е', 'ет')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=1.846; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=-0.013
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.117
# ==================================================
# ('нн', 'я')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=13.558; t_score=1.282
# assoc_agg=2.476 before length penalty
# penalized_score=1.822
# H_bi=0.003; H_unigrams=0.090; info_gain=0.087
# merge_coef=1.909
# ==================================================
# ('нн', 'е')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=4.817; t_score=0.738
# assoc_agg=1.533 before length penalty
# penalized_score=0.879
# H_bi=0.002; H_unigrams=0.112; info_gain=0.111
# merge_coef=0.990
# ==================================================
# ('нн', 'и')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=5.424; t_score=0.767
# assoc_agg=1.630 before length penalty
# penalized_score=0.977
# H_bi=0.002; H_unigrams=0.104; info_gain=0.102
# merge_coef=1.079
# ==================================================
# ('а', 'ла')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=4.310; t_score=3.390
# assoc_agg=2.121 before length penalty
# penalized_score=1.468
# H_bi=0.025; H_unigrams=0.288; info_gain=0.263
# merge_coef=1.730
# ==================================================
# ('е', 'ла')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=1.846; t_score=0.316
# assoc_agg=0.640 before length penalty
# penalized_score=-0.013
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.117
# ==================================================
# ('ан', 'а')
# avg_uni_len=2.5432111302934906; sq_len_penalty=4; relative_len_pen=0.786
# pre_pmi=6.930; t_score=2.712
# assoc_agg=2.342 before length penalty
# penalized_score=1.689
# H_bi=0.013; H_unigrams=0.335; info_gain=0.321
# merge_coef=2.010
# ==================================================
# MIN MAX VALS:
#       0.000;
#       2.230
# ==================================================
# ('а', 'ю')
# avg_uni_len=2.549165309446254; sq_len_penalty=2; relative_len_pen=0.555
# pre_pmi=2.456; t_score=1.188
# assoc_agg=1.213 before length penalty
# penalized_score=1.063
# H_bi=0.008; H_unigrams=0.238; info_gain=0.230
# merge_coef=1.293
# ==================================================
# ('а', 'в')
# avg_uni_len=2.549165309446254; sq_len_penalty=2; relative_len_pen=0.555
# pre_pmi=3.741; t_score=2.293
# assoc_agg=1.812 before length penalty
# penalized_score=1.662
# H_bi=0.014; H_unigrams=0.252; info_gain=0.237
# merge_coef=1.899
# ==================================================
# ('а', 'й')
# avg_uni_len=2.549165309446254; sq_len_penalty=2; relative_len_pen=0.555
# pre_pmi=3.240; t_score=2.199
# assoc_agg=1.687 before length penalty
# penalized_score=1.537
# H_bi=0.015; H_unigrams=0.265; info_gain=0.249
# merge_coef=1.786
# ==================================================
# ('й', 'ся')
# avg_uni_len=2.549165309446254; sq_len_penalty=4; relative_len_pen=0.785
# pre_pmi=5.216; t_score=2.934
# assoc_agg=2.179 before length penalty
# penalized_score=1.529
# H_bi=0.017; H_unigrams=0.389; info_gain=0.371
# merge_coef=1.901
# ==================================================
# ('а', 'ть')
# avg_uni_len=2.549165309446254; sq_len_penalty=4; relative_len_pen=0.785
# pre_pmi=4.565; t_score=3.468
# assoc_agg=2.175 before length penalty
# penalized_score=1.525
# H_bi=0.025; H_unigrams=0.281; info_gain=0.256
# merge_coef=1.781
# ==================================================
# ('а', 'ющ')
# avg_uni_len=2.549165309446254; sq_len_penalty=4; relative_len_pen=0.785
# pre_pmi=3.336; t_score=5.485
# assoc_agg=2.218 before length penalty
# penalized_score=1.568
# H_bi=0.067; H_unigrams=0.468; info_gain=0.401
# merge_coef=1.969
# ==================================================
# ('вш', 'и')
# avg_uni_len=2.549165309446254; sq_len_penalty=4; relative_len_pen=0.785
# pre_pmi=3.585; t_score=2.147
# assoc_agg=1.748 before length penalty
# penalized_score=1.098
# H_bi=0.013; H_unigrams=0.230; info_gain=0.217
# merge_coef=1.315
# ==================================================
# ('л', 'ся')
# avg_uni_len=2.549165309446254; sq_len_penalty=4; relative_len_pen=0.785
# pre_pmi=4.538; t_score=2.041
# assoc_agg=1.893 before length penalty
# penalized_score=1.243
# H_bi=0.010; H_unigrams=0.380; info_gain=0.370
# merge_coef=1.613
# ==================================================
# ('я', 'сь')
# avg_uni_len=2.549165309446254; sq_len_penalty=4; relative_len_pen=0.785
# pre_pmi=10.146; t_score=2.476
# assoc_agg=2.570 before length penalty
# penalized_score=1.920
# H_bi=0.010; H_unigrams=0.203; info_gain=0.193
# ...
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=6.756; t_score=3.039
# assoc_agg=2.385 before length penalty
# penalized_score=1.754
# H_bi=0.017; H_unigrams=0.294; info_gain=0.278
# merge_coef=2.032
# ==================================================
# ('е', 'ть')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=1.927; t_score=0.342
# assoc_agg=0.685 before length penalty
# penalized_score=0.054
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.184
# ==================================================
# ('е', 'ющ')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=6.632; t_score=2.916
# assoc_agg=2.349 before length penalty
# penalized_score=1.718
# H_bi=0.016; H_unigrams=0.285; info_gain=0.270
# merge_coef=1.988
# ==================================================
# ('е', 'ем')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=0.419; t_score=-2.027
# assoc_agg=-0.627 before length penalty
# penalized_score=-1.258
# H_bi=0.002; H_unigrams=0.318; info_gain=0.317
# merge_coef=0.000
# ==================================================
# ('а', 'ют')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=4.404; t_score=2.567
# assoc_agg=1.987 before length penalty
# penalized_score=1.355
# H_bi=0.016; H_unigrams=0.230; info_gain=0.214
# merge_coef=1.570
# ==================================================
# ('е', 'ют')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=2.362; t_score=0.463
# assoc_agg=0.895 before length penalty
# penalized_score=0.263
# H_bi=0.002; H_unigrams=0.117; info_gain=0.115
# merge_coef=0.379
# ==================================================
# ('а', 'ло')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=6.354; t_score=3.838
# assoc_agg=2.471 before length penalty
# penalized_score=1.840
# H_bi=0.025; H_unigrams=0.244; info_gain=0.219
# merge_coef=2.059
# ==================================================
# ('е', 'ло')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=1.927; t_score=0.342
# assoc_agg=0.685 before length penalty
# penalized_score=0.054
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.184
# ==================================================
# ('а', 'ны')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=8.300; t_score=2.810
# assoc_agg=2.491 before length penalty
# penalized_score=1.860
# H_bi=0.014; H_unigrams=0.190; info_gain=0.176
# merge_coef=2.037
# ==================================================
# ('а', 'ли')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=6.354; t_score=3.838
# assoc_agg=2.471 before length penalty
# penalized_score=1.840
# H_bi=0.025; H_unigrams=0.244; info_gain=0.219
# merge_coef=2.059
# ==================================================
# ('е', 'ли')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=1.927; t_score=0.342
# assoc_agg=0.685 before length penalty
# penalized_score=0.054
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.184
# ==================================================
# ('я', 'ми')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=18.614; t_score=0.932
# assoc_agg=2.584 before length penalty
# penalized_score=1.953
# H_bi=0.002; H_unigrams=0.051; info_gain=0.049
# merge_coef=2.002
# ==================================================
# ('а', 'но')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=8.300; t_score=2.810
# assoc_agg=2.491 before length penalty
# penalized_score=1.860
# H_bi=0.014; H_unigrams=0.190; info_gain=0.176
# merge_coef=2.037
# ==================================================
# ('а', 'ет')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=3.591; t_score=2.332
# assoc_agg=1.790 before length penalty
# penalized_score=1.159
# H_bi=0.016; H_unigrams=0.244; info_gain=0.228
# merge_coef=1.388
# ==================================================
# ('е', 'ет')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=1.927; t_score=0.342
# assoc_agg=0.685 before length penalty
# penalized_score=0.054
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.184
# ==================================================
# ('нн', 'я')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=10.705; t_score=0.881
# assoc_agg=2.166 before length penalty
# penalized_score=1.535
# H_bi=0.002; H_unigrams=0.068; info_gain=0.066
# merge_coef=1.601
# ==================================================
# ('нн', 'е')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=4.965; t_score=0.744
# assoc_agg=1.557 before length penalty
# penalized_score=0.926
# H_bi=0.002; H_unigrams=0.111; info_gain=0.109
# merge_coef=1.035
# ==================================================
# ('нн', 'и')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=5.627; t_score=0.775
# assoc_agg=1.660 before length penalty
# penalized_score=1.029
# H_bi=0.002; H_unigrams=0.102; info_gain=0.100
# merge_coef=1.129
# ==================================================
# ('а', 'ла')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=6.354; t_score=3.838
# assoc_agg=2.471 before length penalty
# penalized_score=1.840
# H_bi=0.025; H_unigrams=0.244; info_gain=0.219
# merge_coef=2.059
# ==================================================
# ('е', 'ла')
# avg_uni_len=2.5825513045271733; sq_len_penalty=4; relative_len_pen=0.774
# pre_pmi=1.927; t_score=0.342
# assoc_agg=0.685 before length penalty
# penalized_score=0.054
# H_bi=0.002; H_unigrams=0.131; info_gain=0.130
# merge_coef=0.184
# ==================================================
# MIN MAX VALS:
#       0.000;
#       2.090
# ==================================================
# ('а', 'ю')
# avg_uni_len=2.586018174308137; sq_len_penalty=2; relative_len_pen=0.547
# pre_pmi=3.587; t_score=1.583
# assoc_agg=1.606 before length penalty
# penalized_score=1.477
# H_bi=0.008; H_unigrams=0.197; info_gain=0.188
# merge_coef=1.665
# ==================================================
# ('а', 'ть')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=6.668; t_score=3.883
# assoc_agg=2.513 before length penalty
# penalized_score=1.883
# H_bi=0.025; H_unigrams=0.239; info_gain=0.214
# merge_coef=2.097
# ==================================================
# ('вш', 'и')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=3.721; t_score=2.185
# assoc_agg=1.784 before length penalty
# penalized_score=1.154
# H_bi=0.014; H_unigrams=0.229; info_gain=0.216
# merge_coef=1.370
# ==================================================
# ('й', 'ся')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=4.757; t_score=2.074
# assoc_agg=1.935 before length penalty
# penalized_score=1.306
# H_bi=0.010; H_unigrams=0.382; info_gain=0.371
# merge_coef=1.677
# ==================================================
# ('л', 'ся')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=4.507; t_score=2.032
# assoc_agg=1.886 before length penalty
# penalized_score=1.257
# H_bi=0.010; H_unigrams=0.382; info_gain=0.372
# merge_coef=1.629
# ==================================================
# ('ся', 'м')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=1.553; t_score=0.259
# assoc_agg=0.484 before length penalty
# penalized_score=-0.146
# H_bi=0.003; H_unigrams=0.263; info_gain=0.260
# merge_coef=0.115
# ==================================================
# ('ся', 'х')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=1.553; t_score=0.259
# assoc_agg=0.484 before length penalty
# penalized_score=-0.146
# H_bi=0.003; H_unigrams=0.263; info_gain=0.260
# merge_coef=0.115
# ==================================================
# ('а', 'сь')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=0.272; t_score=-5.174
# assoc_agg=-0.938 before length penalty
# penalized_score=-1.567
# H_bi=0.003; H_unigrams=0.312; info_gain=0.309
# merge_coef=0.000
# ==================================================
# ('а', 'ем')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=3.280; t_score=4.421
# assoc_agg=2.076 before length penalty
# penalized_score=1.447
# H_bi=0.049; H_unigrams=0.426; info_gain=0.377
# merge_coef=1.824
# ==================================================
# ('ем', 'а')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=0.717; t_score=-2.664
# assoc_agg=-0.240 before length penalty
# penalized_score=-0.869
# H_bi=0.015; H_unigrams=0.422; info_gain=0.407
# merge_coef=0.000
# ==================================================
# ('ем', 'ы')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=7.183; t_score=2.852
# assoc_agg=2.395 before length penalty
# penalized_score=1.766
# H_bi=0.015; H_unigrams=0.211; info_gain=0.196
# merge_coef=1.962
# ==================================================
# ('ем', 'о')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=7.183; t_score=2.852
# assoc_agg=2.395 before length penalty
# penalized_score=1.766
# H_bi=0.015; H_unigrams=0.211; info_gain=0.196
# merge_coef=1.962
# ==================================================
# ('е', 'я')
# avg_uni_len=2.586018174308137; sq_len_penalty=2; relative_len_pen=0.547
# pre_pmi=4.389; t_score=0.711
# assoc_agg=1.454 before length penalty
# penalized_score=1.325
# H_bi=0.002; H_unigrams=0.084; info_gain=0.083
# merge_coef=1.408
# ==================================================
# ('е', 'в')
# avg_uni_len=2.586018174308137; sq_len_penalty=2; relative_len_pen=0.547
# pre_pmi=5.259; t_score=0.759
# assoc_agg=1.605 before length penalty
# penalized_score=1.475
# H_bi=0.002; H_unigrams=0.077; info_gain=0.076
# merge_coef=1.551
# ==================================================
# ('е', 'л')
# avg_uni_len=2.586018174308137; sq_len_penalty=2; relative_len_pen=0.547
# pre_pmi=3.490; t_score=0.636
# assoc_agg=1.257 before length penalty
# penalized_score=1.128
# H_bi=0.002; H_unigrams=0.095; info_gain=0.093
# merge_coef=1.221
# ==================================================
# ('е', 'вш')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=6.752; t_score=3.038
# assoc_agg=2.385 before length penalty
# penalized_score=1.755
# H_bi=0.017; H_unigrams=0.294; info_gain=0.278
# merge_coef=2.033
# ==================================================
# ('е', 'ть')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=1.925; t_score=0.341
# assoc_agg=0.684 before length penalty
# penalized_score=0.055
# H_bi=0.002; H_unigrams=0.132; info_gain=0.130
# merge_coef=0.185
# ==================================================
# ('е', 'ющ')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=6.628; t_score=2.915
# assoc_agg=2.349 before length penalty
# penalized_score=1.720
# H_bi=0.016; H_unigrams=0.285; info_gain=0.270
# merge_coef=1.989
# ==================================================
# ('е', 'ем')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=0.419; t_score=-2.030
# assoc_agg=-0.628 before length penalty
# penalized_score=-1.257
# H_bi=0.002; H_unigrams=0.318; info_gain=0.317
# merge_coef=0.000
# ==================================================
# ('а', 'ют')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=4.622; t_score=2.616
# assoc_agg=2.031 before length penalty
# penalized_score=1.402
# H_bi=0.016; H_unigrams=0.225; info_gain=0.209
# merge_coef=1.611
# ==================================================
# ('е', 'ют')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=2.361; t_score=0.462
# assoc_agg=0.894 before length penalty
# penalized_score=0.265
# H_bi=0.002; H_unigrams=0.117; info_gain=0.116
# merge_coef=0.380
# ==================================================
# ('а', 'ло')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=6.668; t_score=3.883
# assoc_agg=2.513 before length penalty
# penalized_score=1.883
# H_bi=0.025; H_unigrams=0.239; info_gain=0.214
# merge_coef=2.097
# ==================================================
# ('е', 'ло')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=1.925; t_score=0.341
# assoc_agg=0.684 before length penalty
# penalized_score=0.055
# H_bi=0.002; H_unigrams=0.132; info_gain=0.130
# merge_coef=0.185
# ==================================================
# ('а', 'ны')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=8.711; t_score=2.833
# assoc_agg=2.531 before length penalty
# penalized_score=1.901
# H_bi=0.014; H_unigrams=0.185; info_gain=0.172
# merge_coef=2.073
# ==================================================
# ('а', 'ли')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=6.668; t_score=3.883
# assoc_agg=2.513 before length penalty
# penalized_score=1.883
# H_bi=0.025; H_unigrams=0.239; info_gain=0.214
# merge_coef=2.097
# ==================================================
# ('е', 'ли')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=1.925; t_score=0.341
# assoc_agg=0.684 before length penalty
# penalized_score=0.055
# H_bi=0.002; H_unigrams=0.132; info_gain=0.130
# merge_coef=0.185
# ==================================================
# ('я', 'ми')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=18.602; t_score=0.932
# assoc_agg=2.584 before length penalty
# penalized_score=1.954
# H_bi=0.002; H_unigrams=0.051; info_gain=0.049
# merge_coef=2.004
# ==================================================
# ('а', 'но')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=8.711; t_score=2.833
# assoc_agg=2.531 before length penalty
# penalized_score=1.901
# H_bi=0.014; H_unigrams=0.185; info_gain=0.172
# merge_coef=2.073
# ==================================================
# ('а', 'ет')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=3.769; t_score=2.392
# assoc_agg=1.838 before length penalty
# penalized_score=1.209
# H_bi=0.016; H_unigrams=0.239; info_gain=0.224
# merge_coef=1.432
# ==================================================
# ('е', 'ет')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=1.925; t_score=0.341
# assoc_agg=0.684 before length penalty
# penalized_score=0.055
# H_bi=0.002; H_unigrams=0.132; info_gain=0.130
# merge_coef=0.185
# ==================================================
# ('нн', 'я')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=10.698; t_score=0.881
# assoc_agg=2.166 before length penalty
# penalized_score=1.536
# H_bi=0.002; H_unigrams=0.068; info_gain=0.066
# merge_coef=1.602
# ==================================================
# ('нн', 'е')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=4.961; t_score=0.744
# assoc_agg=1.557 before length penalty
# penalized_score=0.927
# H_bi=0.002; H_unigrams=0.111; info_gain=0.109
# merge_coef=1.036
# ==================================================
# ('нн', 'и')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=5.624; t_score=0.774
# assoc_agg=1.659 before length penalty
# penalized_score=1.030
# H_bi=0.002; H_unigrams=0.102; info_gain=0.100
# merge_coef=1.130
# ==================================================
# ('а', 'ла')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=6.668; t_score=3.883
# assoc_agg=2.513 before length penalty
# penalized_score=1.883
# H_bi=0.025; H_unigrams=0.239; info_gain=0.214
# merge_coef=2.097
# ==================================================
# ('е', 'ла')
# avg_uni_len=2.586018174308137; sq_len_penalty=4; relative_len_pen=0.773
# pre_pmi=1.925; t_score=0.341
# assoc_agg=0.684 before length penalty
# penalized_score=0.055
# H_bi=0.002; H_unigrams=0.132; info_gain=0.130
# merge_coef=0.185
# ==================================================
# MIN MAX VALS:
#       0.000;
#       2.097
# ==================================================

# %%
tokenizer = MatvejevWordShredder(vocab, merges)
ids = [tokenizer.encode(word) for word in toy_data]
reversed_text = [tokenizer.decode(inx) for inx in ids]
print(*sorted([word for word in reversed_text], reverse=True), sep='\n')
# Out:
# ['про', 'чит', 'ыва', 'ем', 'ыми', ' под', 'пис', 'авш', 'ей', 'ся', ' про', 'чит', 'ыва', 'ющ', 'им', 'ся', ' по', 'пис', 'ыва', 'ем', 'ый', ' за', 'чит', 'ыва', 'вш', 'их', 'ся', ' до', 'чит', 'авш', 'им', 'ся', ' про', 'чит', 'ающ', 'ую', 'ся', ' за', 'чит', 'авш', 'ее', 'ся', ' под', 'пис', 'ыва', 'ть', 'ся', ' под', 'пис', 'а', 'ло', ' пе', 'ре', 'пиш', 'ите', ' про', 'пис', 'ыва', 'ем', 'ых', ' до', 'чит', 'а', 'ло', ' пе', 'ре', 'пис', 'ыва', 'вш', 'их', ' до', 'чит', 'анн', 'ыми', ' за', 'чит', 'ыва', 'ющ', 'ая', ' по', 'чит', 'а', 'ет', ' за', 'чит', 'ыва', 'вш', 'его', 'ся', ' про', 'пис', 'анн', 'ого', ' за', 'чит', 'анн', 'ого', ' по', 'пис', 'а', 'ны', ' под', 'пис', 'ыва', 'ли', ' за', 'чит', 'а', 'ли', 'сь', ' пе', 'ре', 'чит', 'ыва', 'вш', 'ими', 'ся', ' за', 'чит', 'ыва', 'й', 'ся', ' под', 'пис', 'ыва', 'ющ', 'ий', ' на', 'пис', 'ыва', 'ющ', 'ем', 'ся', ' по', 'чит', 'ыва', 'ем', 'ое', ' под', 'пис', 'авш', 'ие', ' ', 'син', 'е', 'вш', 'ее', ' пе', 'ре', 'чит', 'ан', ' пе', 'ре', 'пиш', 'ешь', 'ся', ' до', 'чит', 'авш', 'ем', ' на', 'пиш', 'ущ', 'ей', 'ся', ' под', 'пис', 'анн', 'ые', ' пе', 'ре', 'пиш', 'ущ', 'ая', 'ся', ' на', 'пис', 'а', 'ло', 'сь', ' пе', 'ре', 'пис', 'а', 'ло', ' на', 'пис', 'авш', 'их', 'ся', ' пе', 'ре', 'пис', 'ыва', 'ющ', 'его', 'ся', ' за', 'чит', 'ыва', 'вш', 'ем', ' пе', 'ре', 'чит', 'ыва', 'ющ', 'их', 'ся', ' на', 'пис', 'ыва', 'ем', 'ою', ' под', 'пис', 'ыва', 'ете', ' про', 'чит', 'а', 'ли', ' по', 'пис', 'авш', 'и', ' пе', 'ре', 'пиш', 'ут', ' пе', 'ре', 'чит', 'авш', 'его', 'ся', ' на', 'пис', 'авш', 'им', ' на', 'пиш', 'ущ', 'ий', 'ся', ' ', 'чит', 'анн', 'ое', ' на', 'пис', 'ыва', 'ем', 'ым', ' под', 'пис', 'ал', 'ся', ' под', 'пис', 'ыва', 'ющ', 'ем', ' пе', 'ре', 'пис', 'ыва', 'вш', 'им', ' про', 'пис', 'ыва', 'ло', 'сь', ' про', 'чит', 'авш', 'ей', ' ', 'син', 'е', 'вш', 'ею', ' пе', 'ре', 'чит', 'ыва', 'ем', 'ыми', ' по', 'пиш', 'ет', ' пе', 'ре', 'пис', 'ыва', 'ющ', 'им', ' ', 'чит', 'авш', 'ая', 'ся', ' до', 'чит', 'авш', 'ему', 'ся', ' на', 'пис', 'ыва', 'йте', ' по', 'пис', 'ыва', 'ю', ' до', 'чит', 'ыва', 'ющ', 'им', 'ся', ' ', 'осе', 'нях', ' до', 'чит', 'ыва', 'ющ', 'ем', 'ся', ' на', 'пис', 'авш', 'ей', 'ся', ' по', 'пис', 'ыва', 'ем', 'ой', ' по', 'пиш', 'ите', ' про', 'пис', 'ей', ' до', 'чит', 'анн', 'ое', ' про', 'чит', 'ыва', 'ющ', 'ую', 'ся', ' ', 'син', 'е', 'ло', ' до', 'чит', 'ыва', 'ем', 'ые', ' пе', 'ре', 'пиш', 'ущ', 'ими', 'ся', ' за', 'чит', 'ыва', 'вш', 'его', ' по', 'пис', 'ыва', 'ющ', 'ие', ' ', 'чит', 'а', 'ешь', 'ся', ' под', 'пис', 'ыва', 'вш', 'ему', 'ся', ' пе', 'ре', 'пис', 'анн', 'ое', ' пис', 'авш', 'их', ' пе', 'ре', 'чит', 'ыва', 'вш', 'ею', ' на', 'пис', 'анн', 'ом', ' на', 'пис', 'ыва', 'ющ', 'их', ' ', 'чит', 'а', 'ла', ' по', 'пиш', 'и', ' пе', 'ре', 'пис', 'ыва', 'ющ', 'ая', 'ся', ' ', 'чит', 'ки', ' пе', 'ре', 'чит', 'ыва', 'йте', ' пе', 'ре', 'чит', 'анн', 'ым', ' пе', 'ре', 'чит', 'ающ', 'ею', 'ся', ' про', 'пис', 'ыва', 'ла', ' до', 'чит', 'ыва', 'ют', 'ся', ' на', 'пис', 'а', 'ла', 'сь', ' по', 'чит', 'ыва', 'ющ', 'ие', ' ', 'осе', 'нн', 'я', ' под', 'пис', 'ыва', 'ющ', 'ею', 'ся', ' до', 'чит', 'ыва', 'ло', 'сь', ' до', 'чит', 'ыва', 'ло', ' пе', 'ре', 'пис', 'ыва', 'ющ', 'ей', ' пе', 'ре', 'пиш', 'ущ', 'ем', 'ся', ' про', 'чит', 'ающ', 'ие', 'ся', ' за', 'чит', 'ыва', 'ло', 'сь', ' пе', 'ре', 'пис', 'ыва', 'л', 'ся', ' пе', 'ре', 'пис', 'ыва', 'ющ', 'ее', 'ся', ' за', 'чит', 'анн', 'ый', ' на', 'чит', 'авш', 'им', 'ся', ' пе', 'ре', 'чит', 'ыва', 'ет', ' ', 'син', 'ейш', 'его', ' на', 'пиш', 'ущ', 'ею', 'ся', ' под', 'пис', 'ыва', 'вш', 'ею', 'ся', ' пе', 'ре', 'пис', 'ыва', 'ем', 'ая', ' пе', 'ре', 'чит', 'ающ', 'ие', 'ся', ' про', 'чит', 'ыва', 'ющ', 'ая', ' под', 'пис', 'анн', 'ых', ' про', 'чит', 'анн', 'ое', ' ', 'чит', 'ающ', 'ее', 'ся', ' до', 'чит', 'ыва', 'ть', 'ся', ' под', 'пис', 'ыва', 'йте', 'сь', ' пе', 'ре', 'пиш', 'ущ', 'ему', 'ся', ' пе', 'ре', 'пис', 'ыва', 'ясь', ' пис', 'ав', ' по', 'чит', 'ающ', 'ей', ' ...

# %% [markdown]
# Есть небольшие огрехи, но в целом - очень неплохо !!!

# %%
print(tokenizer.decode(tokenizer.encode(' переписывалась')))
print(tokenizer.decode(tokenizer.encode(' подписавшийся')))
print(tokenizer.decode(tokenizer.encode(' прочитывать')))
print(tokenizer.decode(tokenizer.encode(' почитаться')))
# Out:
# [' пе', 'ре', 'пис', 'ыва', 'ла', 'сь']
# [' под', 'пис', 'авш', 'ий', 'ся']
# [' про', 'чит', 'ыва', 'ть']
# [' по', 'чит', 'а', 'ть', 'ся']

# %%
print(len(merges), merges)

# this line is used to manually adjust the optimal number of merges
# print(merges.index(('син', 'ь')))
# Out:
# 117 [('ы', 'в'), ('в', 'ш'), ('ю', 'щ'), ('ч', 'и'), ('чи', 'т'), (' ', 'п'), ('п', 'и'), ('с', 'я'), ('пи', 'с'), ('с', 'ь'), ('пи', 'ш'), ('ш', 'ь'), ('ь', 'к'), ('т', 'ь'), (' ', 'з'), ('у', 'щ'), ('у', 'ю'), ('г', 'о'), ('ыв', 'а'), (' з', 'а'), ('р', 'о'), ('р', 'е'), (' п', 'о'), ('д', 'о'), (' по', 'д'), (' п', 'ро'), ('п', 'ро'), (' п', 'е'), (' п', 'и'), ('е', 'м'), (' пи', 'с'), (' пи', 'ш'), ('с', 'и'), ('и', 'м'), ('ы', 'м'), ('о', 'м'), ('о', 'с'), ('и', 'х'), ('ы', 'х'), ('си', 'н'), (' ', 'н'), (' н', 'а'), ('н', 'н'), (' ', 'до'), ('т', 'е'), ('ю', 'т'), ('ом', 'у'), ('л', 'о'), ('н', 'ы'), ('ь', 'ю'), ('ы', 'й'), ('ы', 'е'), ('й', 'ш'), ('им', 'и'), ('и', 'й'), ('л', 'и'), ('м', 'и'), ('и', 'е'), ('ым', 'и'), ('о', 'ю'), ('о', 'й'), ('н', 'о'), ('о', 'го'), ('о', 'е'), ('е', 'ю'), ('е', 'й'), ('й', 'те'), ('е', 'т'), ('у', 'т'), ('ос', 'е'), ('е', 'го'), ('е', 'е'), ('е', 'шь'), ('е', 'те'), ('е', 'йш'), ('ем', 'у'), ('ю', 'л'), ('а', 'вш'), ('а', 'я'), ('а', 'нн'), ('л', 'а'), ('я', 'х'), ('я', 'м'), ('к', 'у'), ('ю', 'сь'), ('и', 'те'), ('и', 'сь'), ('ю', 'ю'), ('а', 'н'), ('н', 'ь'), ('н', 'ях'), ('н', 'ям'), ('н', 'ью'), ('н', 'я'), ('н', 'и'), ('н', 'ей'), ('ьк', 'у'), ('к', 'а'), ('ка', 'м'), ('ка', 'х'), ('к', 'и'), ('е', 'к'), ('к', 'е'), ('о', 'к'), ('к', 'ою'), ('к', 'ой'), ('а', 'л'), ('у', 'сь'), ('я', 'сь'), ('я', 'я'), ('ан', 'а'), ('а', 'ющ'), ('а', 'в'), ('ьк', 'а'), ('ьк', 'и'), ('ьк', 'е'), ('а', 'й')]

# %%
tokenizer = MatvejevWordShredder(vocab, merges)
tokenizer.push_to_hub(REPO_NAME)

# %%
tokenizer = MatvejevWordShredder.from_pretrained(REPO_NAME)
# Out:
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# merges.json: 0.00B [00:00, ?B/s]
# vocabulary.json: 0.00B [00:00, ?B/s]

# %% [markdown]
# # ***To be continued...***
# В скором времени мы планируем создать полноценную библиотеку, производящую токенизацию, измерить качество разбиений с помощью метрик (а не на глаз), выложить в открытый доступ предобученные токенизаторы для нескольких крупных морфологически богатых языков, и сравнить модели, обученные на наших токенах с моделями, обученными на стандартном `cBPE`, заодно применив в них `Multi-Token Prediction`.
